# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales=pd.read_csv(r'C:\Users\hp\ss\Analytics Vidhya\train_sales.csv')

# %%
sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sales.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sales.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
def lowfat(sale):
    if sale=='Low Fat' or sale=='LF' or sale=='low fat':
        return 1
    elif sale=='Regular' or sale=='reg':
        return 0
sales['fat_content']=sales['Item_Fat_Content'].apply(lambda x: lowfat(x))

# %%
sales=sales.drop('Item_Fat_Content',axis=1)

# %%
sales.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# fat_content                  8523 non-null int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 799.2+ KB

# %%
sales.Item_Identifier
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
sales['food_cat']=sales['Item_Identifier'].str[0:2]

# %%
sales=sales.drop('Item_Identifier',axis=1)

# %%
sales=sales.drop('Item_Type',axis=1)

# %%
sales.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP Outlet_Identifier  \
# 0         9.30         0.016047  249.8092            OUT049
# 1         5.92         0.019278   48.2692            OUT018
# 2        17.50         0.016760  141.6180            OUT049
# 3        19.20         0.000000  182.0950            OUT010
# 4         8.93         0.000000   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  fat_content food_cat
# 0  Supermarket Type1          3735.1380            1       FD
# 1  Supermarket Type2           443.4228            0       DR
# ...

# %%
sales.Item_Visibility=sales.Item_Visibility.replace(0.00,sales.Item_Visibility.mean())

# %%
sales.Item_Weight.fillna(sales.Item_Weight.mean(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
mod=['Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type','food_cat']

# %%
for i in mod:
    sales[i]=le.fit_transform(sales[i])

# %%
sales=pd.get_dummies(sales,columns=mod)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 29 columns):
# Item_Weight                  8523 non-null float64
# Item_Visibility              8523 non-null float64
# Item_MRP                     8523 non-null float64
# Outlet_Establishment_Year    8523 non-null int64
# Item_Outlet_Sales            8523 non-null float64
# fat_content                  8523 non-null int64
# Outlet_Identifier_0          8523 non-null uint8
# Outlet_Identifier_1          8523 non-null uint8
# Outlet_Identifier_2          8523 non-null uint8
# Outlet_Identifier_3          8523 non-null uint8
# Outlet_Identifier_4          8523 non-null uint8
# Outlet_Identifier_5          8523 non-null uint8
# Outlet_Identifier_6          8523 non-null uint8
# Outlet_Identifier_7          8523 non-null uint8
# Outlet_Identifier_8          8523 non-null uint8
# Outlet_Identifier_9          8523 non-null uint8
# Outlet_Size_0                8523 non-null uint8
# ...

# %%
Y=sales['Item_Outlet_Sales']

# %%
X=sales.drop(['Item_Outlet_Sales'],axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 28 columns):
# Item_Weight                  8523 non-null float64
# Item_Visibility              8523 non-null float64
# Item_MRP                     8523 non-null float64
# Outlet_Establishment_Year    8523 non-null int64
# fat_content                  8523 non-null int64
# Outlet_Identifier_0          8523 non-null uint8
# Outlet_Identifier_1          8523 non-null uint8
# Outlet_Identifier_2          8523 non-null uint8
# Outlet_Identifier_3          8523 non-null uint8
# Outlet_Identifier_4          8523 non-null uint8
# Outlet_Identifier_5          8523 non-null uint8
# Outlet_Identifier_6          8523 non-null uint8
# Outlet_Identifier_7          8523 non-null uint8
# Outlet_Identifier_8          8523 non-null uint8
# Outlet_Identifier_9          8523 non-null uint8
# Outlet_Size_0                8523 non-null uint8
# Outlet_Size_1                8523 non-null uint8
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(X,Y)
# Out:
# 0.5634815934605311

# %%
test=pd.read_csv(r'C:\Users\hp\ss\Analytics Vidhya\test_sales.csv')

# %%
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test.Item_Weight.fillna(test.Item_Weight.mean(),inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
# Item_Identifier              5681 non-null object
# Item_Weight                  5681 non-null float64
# Item_Fat_Content             5681 non-null object
# Item_Visibility              5681 non-null float64
# Item_Type                    5681 non-null object
# Item_MRP                     5681 non-null float64
# Outlet_Identifier            5681 non-null object
# Outlet_Establishment_Year    5681 non-null int64
# Outlet_Size                  4075 non-null object
# Outlet_Location_Type         5681 non-null object
# Outlet_Type                  5681 non-null object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test.Outlet_Size.fillna('Medium',inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
# Item_Identifier              5681 non-null object
# Item_Weight                  5681 non-null float64
# Item_Fat_Content             5681 non-null object
# Item_Visibility              5681 non-null float64
# Item_Type                    5681 non-null object
# Item_MRP                     5681 non-null float64
# Outlet_Identifier            5681 non-null object
# Outlet_Establishment_Year    5681 non-null int64
# Outlet_Size                  5681 non-null object
# Outlet_Location_Type         5681 non-null object
# Outlet_Type                  5681 non-null object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test['food_cat']=test['Item_Identifier'].str[0:2]

# %%
test=test.drop('Item_Identifier',axis=1)

# %%
test=test.drop('Item_Type',axis=1)

# %%
test.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP Outlet_Identifier  \
# 0    20.750000          Low Fat         0.007565  107.8622            OUT049
# 1     8.300000              reg         0.038428   87.3198            OUT017
# 2    14.600000          Low Fat         0.099575  241.7538            OUT010
# 3     7.315000          Low Fat         0.015388  155.0340            OUT017
# 4    12.695633          Regular         0.118599  234.2300            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
# 2                       1998      Medium               Tier 3
# 3                       2007      Medium               Tier 2
# 4                       1985      Medium               Tier 3
#
#          Outlet_Type food_cat
# 0  Supermarket Type1       FD
# 1  Supermarket Type1       FD
# 2      Grocery Store       NC
# ...

# %%
def lowfat(sale):
    if sale=='Low Fat' or sale=='LF' or sale=='low fat':
        return 1
    elif sale=='Regular' or sale=='reg':
        return 0
test['fat_content']=test['Item_Fat_Content'].apply(lambda x: lowfat(x))

# %%
test=test.drop('Item_Fat_Content',axis=1)

# %%
test.Item_Visibility=test.Item_Visibility.replace(0.00,test.Item_Visibility.mean())

# %%
test
# Out:
#       Item_Weight  Item_Visibility  Item_MRP Outlet_Identifier  \
# 0       20.750000         0.007565  107.8622            OUT049
# 1        8.300000         0.038428   87.3198            OUT017
# 2       14.600000         0.099575  241.7538            OUT010
# 3        7.315000         0.015388  155.0340            OUT017
# 4       12.695633         0.118599  234.2300            OUT027
# ...           ...              ...       ...               ...
# 5676    10.500000         0.013496  141.3154            OUT046
# 5677     7.600000         0.142991  169.1448            OUT018
# 5678    10.000000         0.073529  118.7440            OUT045
# 5679    15.300000         0.065684  214.6218            OUT017
# 5680     9.500000         0.104720   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007      Medium               Tier 2
# ...

# %%
mod=['Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type','food_cat']

# %%
sales['Outlet_S'] = le.fit_transform(sales['Outlet_Size'])
sales=pd.get_dummies(sales,columns=['Outlet_S'])
# Out:
# LabelEncoder()

# %%
data['Outlet'] = le.fit_transform(data['Outlet_Identifier'])

# %%
for i in mod:
    test[i]=le.fit_transform(test[i])

# %%
test=pd.get_dummies(test,columns=mod)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 28 columns):
# Item_Weight                  5681 non-null float64
# Item_Visibility              5681 non-null float64
# Item_MRP                     5681 non-null float64
# Outlet_Establishment_Year    5681 non-null int64
# fat_content                  5681 non-null int64
# Outlet_Identifier_0          5681 non-null uint8
# Outlet_Identifier_1          5681 non-null uint8
# Outlet_Identifier_2          5681 non-null uint8
# Outlet_Identifier_3          5681 non-null uint8
# Outlet_Identifier_4          5681 non-null uint8
# Outlet_Identifier_5          5681 non-null uint8
# Outlet_Identifier_6          5681 non-null uint8
# Outlet_Identifier_7          5681 non-null uint8
# Outlet_Identifier_8          5681 non-null uint8
# Outlet_Identifier_9          5681 non-null uint8
# Outlet_Size_0                5681 non-null uint8
# Outlet_Size_1                5681 non-null uint8
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 29 columns):
# Item_Weight                  8523 non-null float64
# Item_Visibility              8523 non-null float64
# Item_MRP                     8523 non-null float64
# Outlet_Establishment_Year    8523 non-null int64
# Item_Outlet_Sales            8523 non-null float64
# fat_content                  8523 non-null int64
# Outlet_Identifier_0          8523 non-null uint8
# Outlet_Identifier_1          8523 non-null uint8
# Outlet_Identifier_2          8523 non-null uint8
# Outlet_Identifier_3          8523 non-null uint8
# Outlet_Identifier_4          8523 non-null uint8
# Outlet_Identifier_5          8523 non-null uint8
# Outlet_Identifier_6          8523 non-null uint8
# Outlet_Identifier_7          8523 non-null uint8
# Outlet_Identifier_8          8523 non-null uint8
# Outlet_Identifier_9          8523 non-null uint8
# Outlet_Size_0                8523 non-null uint8
# ...

# %%
final=pd.DataFrame(model.predict(test),columns=['Item_Outlet_Sales'])

# %%
final
# Out:
#       Item_Outlet_Sales
# 0           1844.264127
# 1           1572.695566
# 2           1875.195575
# 3           2590.474169
# 4           5183.428468
# ...                 ...
# 5676        2313.551505
# 5677        2441.122800
# 5678        1811.071925
# 5679        3542.466010
# 5680        1267.604540
#
# [5681 rows x 1 columns]

# %%
test
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       20.750000         0.007565  107.8622                       1999
# 1        8.300000         0.038428   87.3198                       2007
# 2       14.600000         0.099575  241.7538                       1998
# 3        7.315000         0.015388  155.0340                       2007
# 4       12.695633         0.118599  234.2300                       1985
# ...           ...              ...       ...                        ...
# 5676    10.500000         0.013496  141.3154                       1997
# 5677     7.600000         0.142991  169.1448                       2009
# 5678    10.000000         0.073529  118.7440                       2002
# 5679    15.300000         0.065684  214.6218                       2007
# 5680     9.500000         0.104720   79.7960                       2002
#
#       fat_content  Outlet_Identifier_0  Outlet_Identifier_1  \
# ...

# %%
sub=pd.read_csv(r'C:\Users\hp\ss\Analytics Vidhya\test_sales.csv')

# %%
item_id=sub[['Item_Identifier','Outlet_Identifier']]

# %%
item_id
# Out:
#      Item_Identifier Outlet_Identifier
# 0              FDW58            OUT049
# 1              FDW14            OUT017
# 2              NCN55            OUT010
# 3              FDQ58            OUT017
# 4              FDY38            OUT027
# ...              ...               ...
# 5676           FDB58            OUT046
# 5677           FDD47            OUT018
# 5678           NCO17            OUT045
# 5679           FDJ26            OUT017
# 5680           FDU37            OUT045
#
# [5681 rows x 2 columns]

# %%
final=pd.concat([item_id,final],axis=1)

# %%
final.to_csv('submission.csv')

# %%
def f(sale):
    if sale<=0:
        return 0
final['Item_Outlet_Sales']=final['Item_Outlet_Sales'].apply(lambda x: f(x))

# %%
sns.distplot(final)

# %%
final[final<0]=0

# %%
final
# Out:
#       Item_Outlet_Sales
# 0           1844.264127
# 1           1572.695566
# 2           1875.195575
# 3           2590.474169
# 4           5183.428468
# ...                 ...
# 5676        2313.551505
# 5677        2441.122800
# 5678        1811.071925
# 5679        3542.466010
# 5680        1267.604540
#
# [5681 rows x 1 columns]
